# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahgloria070713-design/cs1-python-diamond-gloria/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = input("Enter first number:")
num2 = input("Enter second number:")
num3 = input("Enter third number:")

biggest = max(num1,num2,num3)
print(f"The biggest number is :{biggest}")
# Out:
# Enter first number:12
# Enter second number:34
# Enter third number:20
# The biggest number is :34
