# %% [markdown]
# <a href="https://colab.research.google.com/github/mariahgloria070713-design/cs1-python-diamond-gloria/blob/main/codingCS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import IFrame

print ("minahal kaba?")
answer = input("")
print ("alam mo ba kung bakit ka nasaksaktan?")
answer2 = input("")
print ("iniisip mo kasi na gusto ka rin niya. Kahit hindi naman. Umaasa ka lang...")

IFrame(src="https://www.youtube-nocookie.com", width="560", height="315")
# Out:
# minahal kaba?
# oo\
# alam mo ba kung bakit ka nasaksaktan?
# bakit
# iniisip mo kasi na gusto ka rin niya. Kahit hindi naman. Umaasa ka lang...
#         <iframe
#             width="560"
#             height="315"
#             src="https://www.youtube-nocookie.com"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
